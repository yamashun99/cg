# %%
import numpy as np

# %%
N = 100
A = np.random.rand(N, N)
A = A @ A.T
b = np.random.rand(N)

# %%
# x = np.random.rand(N)
x = np.zeros(N)
r = b - A @ x

# %%
for i in range(100000):
    alpha = (r @ r) / (r @ A @ r)
    x = x + alpha * r
    r = b - A @ x
    print(np.linalg.norm(r))
# Out:
# 43.65896080864213
# 20.3132427203281
# 18.040777824584747
# 19.742007860436804
# 17.538285929753087
# 19.197967370344642
# 17.059617255862953
# 18.679598632982472
# 16.60343643646557
# 18.18546098299902
# 16.168480298195956
# 17.714192027813365
# 15.753554605080149
# 17.264504098572008
# 15.357530916146251
# 16.835180822801284
# 14.979343549547195
# 16.425073811916803
# 14.617986647584814
# 16.033099458002336
# 14.272511338097404
# 15.658235835388775
# 13.942022988617836
# 15.299519703540268
# 13.625678550528924
# 14.956043608586542
# 13.32268399112514
# 14.626953081524853
# 13.032291812048985
# 14.311443931658971
# 12.753798652999363
# 14.008759634254014
# 12.486542979925543
# 13.718188811669997
# 12.229902857129192
# 13.439062807414654
# 11.98329380281148
# 13.17075335263206
# 11.746166727636147
# 12.912670324540565
# 11.518005955843568
# 12.664259596258782
# 11.298327328362975
# 12.425000977334385
# 11.086676387234936
# 12.194406244121328
# 10.882626640496815
# 11.972017258960129
# ...
